# %%
from IPython.display import Image, display

image_files = [
    '/content/01_eda_overview.png',
    '/content/03_elbow_historical.png',
    '/content/03_shap_pregame_importance.png',
    '/content/05_shap_explanatory_beeswarm.png',
    '/content/05_shap_explanatory_importance.png'
]

for file_path in image_files:
    file_name = file_path.split('/')[-1]
    print(f'{file_name}:')
    display(Image(file_path))
    print('\n')
# Out:
# 01_eda_overview.png:
# 03_elbow_historical.png:
# 03_shap_pregame_importance.png:
# 05_shap_explanatory_beeswarm.png:
# 05_shap_explanatory_importance.png:
